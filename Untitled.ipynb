# %%
import requests
response = requests.get('https://data.police.uk/api/crimes-street-dates')
print(response.status_code)
# Out:
# 200

# %%
import json
dict1 = response.json()

# %%
# dict1

# %%
# dict1[0]['stop-and-search']

# %%
# import csv
# data_file = open('file1.csv','w',newline='')
# csv_writer = csv.writer(data_file)

# count = 0
# for data in dict1:
#     if count == 0:
#         header = data.keys()
#         csv_writer.writerow(header)
#         count += 1
#         values = dict1[0:]['stop-and-search']
#     csv_writer.writerow(values)
# data_file.close()

# %%
import json

out_file = open("myfile.json", "w") 
    
json.dump(dict1, out_file) 
    
out_file.close()

# %%
import json
import csv
with open('myfile.json') as json_file:
    jsondata = json.load(json_file)
 
data_file = open('jsonoutput1.csv', 'w', newline='')
csv_writer = csv.writer(data_file)
 
count = 0
for data in jsondata:
    if count == 0:
        header = data.keys()
        csv_writer.writerow(header)
        count += 1
        values = [i[0:] for i in data.values()]
    csv_writer.writerow(values)
 
data_file.close()

# %%
import pandas as pd
df = pd.read_csv('jsonoutput1.csv')

# %%
df.head()
# Out:
#       date                                    stop-and-search
# 0  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 1  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 2  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 3  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 4  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...

# %%
res = []
for i in df['stop-and-search']:
    res.append(i[1:571])

# %%
# res[0]

# %%
dict2 = {'date':df['date'], 'stop-and-search':res}

# %%
df2 = pd.DataFrame(dict2)

# %%
df2.head()
# Out:
#       date                                    stop-and-search
# 0  2021-10  'avon-and-somerset', 'bedfordshire', 'btp', 'c...
# 1  2021-10  'avon-and-somerset', 'bedfordshire', 'btp', 'c...
# 2  2021-10  'avon-and-somerset', 'bedfordshire', 'btp', 'c...
# 3  2021-10  'avon-and-somerset', 'bedfordshire', 'btp', 'c...
# 4  2021-10  'avon-and-somerset', 'bedfordshire', 'btp', 'c...

# %%
df.to_csv('crime_street.csv', index= False)

# %%
df2 = pd.read_csv('crime_street.csv')

# %%
df2
# Out:
#        date                                    stop-and-search
# 0   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 1   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 2   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 3   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 4   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 5   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 6   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 7   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 8   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 9   2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 10  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 11  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 12  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 13  2021-10  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# ...
